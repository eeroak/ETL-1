# %%
import pandas as pd
import os

# %%
data = pd.read_csv("EVPData.csv", low_memory=False)
data.head(5)
# Out:
#    VIN (1-10)   County                 City                       State   \
# 0  3C3CFFGE4E   Yakima                 Yakima                     WA
# 1  5YJXCBE40H   Thurston               Olympia                    WA
# 2  3MW39FS03P   King                   Renton                     WA
# 3  7PDSGABA8P   Snohomish              Bothell                    WA
# 4  5YJ3E1EB8L   King                   Kent                       WA
#
#    Postal Code   Model Year   Make                   \
# 0        98902          2014  FIAT
# 1        98513          2017  TESLA
# 2        98058          2023  BMW
# 3        98012          2023  RIVIAN
# 4        98031          2020  TESLA
#
#    Model                      Electric Vehicle Type                    \
# 0  500                        Battery Electric Vehicle (BEV)
# 1  MODEL X                    Battery Electric Vehicle (BEV)
# 2  330E                       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
#print(data.isna().sum()) # Check for missing values
#print(data.duplicated().sum()) # Check for duplicates

# %%
# Cleaning the data
data = data.fillna(data.mean()) # Fill missing values with the mean of the column
data = data.drop_duplicates() # Remove duplicates

# %%
# Save the data to the same file, overwriting the original
#data.to_csv('/data/Electric_Vehicle_Population_Data.csv', index=False)
